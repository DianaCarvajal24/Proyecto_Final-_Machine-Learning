# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

#Llamado de la lista de datos
data = pd.read_csv('/archivo_cvs/BD_transfusion.csv')
#HEAD nos muestra los 5 primeros registros
data.head()
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  \
# 0                 2                 50                  12500             98
# 1                 0                 13                   3250             28
# 2                 1                 16                   4000             35
# 3                 2                 20                   5000             45
# 4                 1                 24                   6000             77
#
#    he/she donated
# 0               1
# 1               1
# 2               1
# 3               1
# 4               0

# %%
data
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  he/she donated
# 0               98               1
# 1               28               1
# 2               35               1
# 3               45               1
# ...

# %%
#SHAOE nos indica la cantida de filas u columnas 
data.shape
# Out:
# (748, 5)

# %%
# DESCRIBE analisis exploratorio (Cantidad , la media , desviacion , valor max y min y percentiles)
data.describe()
# Out:
#        Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# count        748.000000         748.000000             748.000000
# mean           9.506684           5.514706            1378.676471
# std            8.095396           5.839307            1459.826781
# min            0.000000           1.000000             250.000000
# 25%            2.750000           2.000000             500.000000
# 50%            7.000000           4.000000            1000.000000
# 75%           14.000000           7.000000            1750.000000
# max           74.000000          50.000000           12500.000000
#
#        Time (months)  he/she donated
# count     748.000000      748.000000
# mean       34.282086        0.237968
# std        24.376714        0.426124
# min         2.000000        0.000000
# 25%        16.000000        0.000000
# 50%        28.000000        0.000000
# 75%        50.000000        0.000000
# max        98.000000        1.000000

# %%
# Muesta la informacion de los datos (feature)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Recency (months)       748 non-null    int64
#  1   Frequency (times)      748 non-null    int64
#  2   Monetary (c.c. blood)  748 non-null    int64
#  3   Time (months)          748 non-null    int64
#  4   he/she donated         748 non-null    int64
# dtypes: int64(5)
# memory usage: 29.3 KB

# %%
data['Frequency (times)'].value_counts(dropna=False)
# Out:
# 1     158
# 2     112
# 3      87
# 4      62
# 5      62
# 6      52
# 7      43
# 8      31
# 9      24
# 11     22
# 12     14
# 10     14
# 14     13
# 16     13
# 13      9
# 15      6
# 17      4
# 24      3
# 21      2
# 19      2
# 20      2
# 22      2
# 34      1
# 41      1
# 26      1
# 44      1
# 50      1
# 43      1
# 38      1
# 18      1
# 23      1
# 46      1
# 33      1
# Name: Frequency (times), dtype: int64

# %%
#Label
data[['he/she donated']]
# Out:
#      he/she donated
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 0
# ..              ...
# 743               0
# 744               0
# 745               0
# 746               0
# 747               0
#
# [748 rows x 1 columns]

# %%
data
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# ..                ...                ...                    ...
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  he/she donated
# 0               98               1
# 1               28               1
# 2               35               1
# 3               45               1
# ...

# %%
data.drop(['he/she donated'],1).hist()
plt.show()
# Out:
# C:\Users\dcarvasa\AppData\Local\Temp\ipykernel_3896\2961748206.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data.drop(['he/she donated'],1).hist()

# %%
#Agrupacion y relacion de cada uno (Analisis para supervisado y no supervisado)
sb.pairplot(data.dropna(), hue='he/she donated',size=4,vars=["Recency (months)","Frequency (times)","Monetary (c.c. blood)","Time (months)"],kind='scatter')
# Out:
# C:\Users\dcarvasa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
